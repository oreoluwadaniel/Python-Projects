# %%
import numpy as np
import pandas as pd

df = pd.read_excel("C:/Users/USER/Videos/Career/data/new data/Online Retail.xlsx")
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  541909.000000
# mean        9.552250       4.611114   15287.518434
# std       218.081158      96.759853    1484.746041
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   14367.000000
# 50%         3.000000       2.080000   15287.000000
# 75%        10.000000       4.130000   16255.000000
# max     80995.000000   38970.000000   18287.000000

# %%
df['Country']
# Out:
# 0         United Kingdom
# 1         United Kingdom
# 2         United Kingdom
# 3         United Kingdom
# 4         United Kingdom
#                ...
# 541904            France
# 541905            France
# 541906            France
# 541907            France
# 541908            France
# Name: Country, Length: 541909, dtype: object

# %%
type(df['Country'])
# Out:
# pandas.core.series.Series

# %%
df['Country'][304366]
# Out:
# 'United Kingdom'

# %%
df.at[541908, 'Country']
# Out:
# 'France'

# %%
df.Description
# Out:
# 0          WHITE HANGING HEART T-LIGHT HOLDER
# 1                         WHITE METAL LANTERN
# 2              CREAM CUPID HEARTS COAT HANGER
# 3         KNITTED UNION FLAG HOT WATER BOTTLE
# 4              RED WOOLLY HOTTIE WHITE HEART.
#                          ...
# 541904            PACK OF 20 SPACEBOY NAPKINS
# 541905           CHILDREN'S APRON DOLLY GIRL
# 541906          CHILDRENS CUTLERY DOLLY GIRL
# 541907        CHILDRENS CUTLERY CIRCUS PARADE
# 541908          BAKING SET 9 PIECE RETROSPOT
# Name: Description, Length: 541909, dtype: object

# %%
dff = df[['InvoiceDate', 'UnitPrice']]
dff
# Out:
#                InvoiceDate  UnitPrice
# 0      2010-12-01 08:26:00       2.55
# 1      2010-12-01 08:26:00       3.39
# 2      2010-12-01 08:26:00       2.75
# 3      2010-12-01 08:26:00       3.39
# 4      2010-12-01 08:26:00       3.39
# ...                    ...        ...
# 541904 2011-12-09 12:50:00       0.85
# 541905 2011-12-09 12:50:00       2.10
# 541906 2011-12-09 12:50:00       4.15
# 541907 2011-12-09 12:50:00       4.15
# 541908 2011-12-09 12:50:00       4.95
#
# [541909 rows x 2 columns]

# %%
#retrieve a specific row
df.loc[345]
# Out:
# InvoiceNo                         536401
# StockCode                          21907
# Description    I'M ON HOLIDAY METAL SIGN
# Quantity                               2
# InvoiceDate          2010-12-01 11:21:00
# UnitPrice                            2.1
# CustomerID                         15862
# Country                   United Kingdom
# Name: 345, dtype: object

# %%
type(df.loc[345])
# Out:
# pandas.core.series.Series

# %%
df.tail(7)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541902    581587     22629              SPACEBOY LUNCH BOX         12
# 541903    581587     23256      CHILDRENS CUTLERY SPACEBOY          4
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID Country
# 541902 2011-12-09 12:50:00       1.95       12680  France
# 541903 2011-12-09 12:50:00       4.15       12680  France
# 541904 2011-12-09 12:50:00       0.85       12680  France
# 541905 2011-12-09 12:50:00       2.10       12680  France
# 541906 2011-12-09 12:50:00       4.15       12680  France
# ...

# %%
df.loc[15:20]
# Out:
#    InvoiceNo StockCode                     Description  Quantity  \
# 15    536367     22623   BOX OF VINTAGE JIGSAW BLOCKS          3
# 16    536367     22622  BOX OF VINTAGE ALPHABET BLOCKS         2
# 17    536367     21754        HOME BUILDING BLOCK WORD         3
# 18    536367     21755        LOVE BUILDING BLOCK WORD         3
# 19    536367     21777     RECIPE BOX WITH METAL HEART         4
# 20    536367     48187             DOORMAT NEW ENGLAND         4
#
#            InvoiceDate  UnitPrice  CustomerID         Country
# 15 2010-12-01 08:34:00       4.95       13047  United Kingdom
# 16 2010-12-01 08:34:00       9.95       13047  United Kingdom
# 17 2010-12-01 08:34:00       5.95       13047  United Kingdom
# 18 2010-12-01 08:34:00       5.95       13047  United Kingdom
# 19 2010-12-01 08:34:00       7.95       13047  United Kingdom
# 20 2010-12-01 08:34:00       7.95       13047  United Kingdom

# %%
df.sample(14)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 284385    561870     22423             REGENCY CAKESTAND 3 TIER         1
# 332270    566060     22784                LANTERN CREAM GAZEBO          2
# 178129    552229    84535B         FAIRY CAKES NOTEBOOK A6 SIZE         1
# 426780    573363     22910    PAPER CHAIN KIT VINTAGE CHRISTMAS        40
# 469820    576611     23084                   RABBIT NIGHT LIGHT        10
# 131755    547644     22776          SWEETHEART CAKESTAND 3 TIER         4
# 525348    580615     23126            FELTCRAFT GIRL AMELIE KIT         8
# 5840      536876     22358              KINGS CHOICE TEA CADDY          1
# 21077     538071     22665    RECIPE BOX BLUE SKETCHBOOK DESIGN         2
# 193048    553505     23110              PARISIENNE KEY CABINET          2
# 179929    552291     84755  COLOUR GLASS T-LIGHT HOLDER HANGING        16
# 488782    577850     23356                LOVE HOT WATER BOTTLE         6
# ...

# %%
total_country=df.Country.sum()

# %%
total_customer=df.CustomerID.count()

# %%
rate = total_customer / total_country

# %%
df.sort_values('Quantity', ascending=False).head(20)
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 540421    581483     23843          PAPER CRAFT , LITTLE BIRDIE     80995
# 61619     541431     23166       MEDIUM CERAMIC TOP STORAGE JAR     74215
# 502122    578841     84826       ASSTD DESIGN 3D PAPER STICKERS     12540
# 74614     542504     37413                                  NaN      5568
# 421632    573008     84077    WORLD WAR 2 GLIDERS ASSTD DESIGNS      4800
# 206121    554868     22197                 SMALL POPCORN HOLDER      4300
# 220843    556231    85123A                                    ?      4000
# 97432     544612     22053                EMPIRE DESIGN ROSETTE      3906
# 270885    560599     18007  ESSENTIAL BALM 3.5g TIN IN ENVELOPE      3186
# 160546    550461     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 52711     540815     21108   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114
# 263885    560040     23343                  came coded as 20713      3100
# ...

# %%
df.InvoiceDate
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
dt['InvoiceDate'] = pd.to_datetime(df.InvoiceDate)
dt['InvoiceDate']
# Out:
# 0        2010-12-01 08:26:00
# 1        2010-12-01 08:26:00
# 2        2010-12-01 08:26:00
# 3        2010-12-01 08:26:00
# 4        2010-12-01 08:26:00
#                  ...
# 541904   2011-12-09 12:50:00
# 541905   2011-12-09 12:50:00
# 541906   2011-12-09 12:50:00
# 541907   2011-12-09 12:50:00
# 541908   2011-12-09 12:50:00
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
dtyear=pd.DatetimeIndex(df.InvoiceDate).year
dtmonth=pd.DatetimeIndex(df.InvoiceDate).month
dtday=pd.DatetimeIndex(df.InvoiceDate).day
dtweekday=pd.DatetimeIndex(df.InvoiceDate).weekday

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
dfm=df(df.month == 5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-ea927c42ba19> in <module>
# ----> 1 dfm=df(df.month == 5)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'month'

# %%
df.Quantity.plot(kind='bar');
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-69-0c26d610695f> in <module>
# ----> 1 df.Quantity.plot(kind='bar');
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     792                     data.columns = label_name
#     793
# --> 794         return plot_backend.plot(data, kind=kind, **kwargs)
#     795
#     796     def line(self, x=None, y=None, **kwargs):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      60             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      61     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 62     plot_obj.generate()
#      63     plot_obj.draw()
#      64     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     279         self._compute_plot_data()
# ...

# %%
df.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
ct=df.Country.value_counts().head(7)
ct
# Out:
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Netherlands         2371
# Belgium             2069
# Name: Country, dtype: int64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize =(15, 3))
plt.xticks(rotation=75)
sns.barplot(ct.index, ct)

# %%
['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
       'UnitPrice', 'CustomerID', 'Country'],
      dtype='object')

# %%
plt.figure(figsize =(12, 6))
plt.title("Quantities")
plt.xlabel('Quantity')
plt.ylabel('Number of Respondent')

plt.hist(df.Quantity, bins=np.arange(10,100,5), color='purple');
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-db6e7221453d> in <module>
# ----> 1 plt.figure(figsize =(12, 6))
#       2 plt.title("Quantities")
#       3 plt.xlabel('Quantity')
#       4 plt.ylabel('Number of Respondent')
#       5
#
# NameError: name 'plt' is not defined
